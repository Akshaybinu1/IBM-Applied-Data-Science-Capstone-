# %%
pip install jupyter-dash dash plotly pandas
# Out:
# Collecting jupyter-dash
#   Obtaining dependency information for jupyter-dash from https://files.pythonhosted.org/packages/38/62/2c51aeb18c6d765c03c911e4d70f029ccb9de1a991d88cf30e362d2433c9/jupyter_dash-0.4.2-py3-none-any.whl.metadata
#   Downloading jupyter_dash-0.4.2-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: dash in c:\users\aksha\anaconda3\lib\site-packages (2.18.2)
# Requirement already satisfied: plotly in c:\users\aksha\anaconda3\lib\site-packages (5.9.0)
# Requirement already satisfied: pandas in c:\users\aksha\anaconda3\lib\site-packages (2.0.3)
# Requirement already satisfied: requests in c:\users\aksha\anaconda3\lib\site-packages (from jupyter-dash) (2.32.3)
# Requirement already satisfied: flask in c:\users\aksha\anaconda3\lib\site-packages (from jupyter-dash) (2.2.2)
# Requirement already satisfied: retrying in c:\users\aksha\anaconda3\lib\site-packages (from jupyter-dash) (1.3.4)
# Requirement already satisfied: ipython in c:\users\aksha\anaconda3\lib\site-packages (from jupyter-dash) (8.15.0)
# Requirement already satisfied: ipykernel in c:\users\aksha\anaconda3\lib\site-packages (from jupyter-dash) (6.25.0)
# Collecting ansi2html (from jupyter-dash)
#   Obtaining dependency information for ansi2html from https://files.pythonhosted.org/packages/bd/71/aee71b836e9ee2741d5694b80d74bfc7c8cd5dbdf7a9f3035fcf80d792b1/ansi2html-1.9.2-py3-none-any.whl.metadata
#   Downloading ansi2html-1.9.2-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: nest-asyncio in c:\users\aksha\anaconda3\lib\site-packages (from jupyter-dash) (1.5.6)
# Requirement already satisfied: Werkzeug<3.1 in c:\users\aksha\anaconda3\lib\site-packages (from dash) (2.2.3)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\aksha\anaconda3\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\aksha\anaconda3\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\aksha\anaconda3\lib\site-packages (from dash) (5.0.0)
# Requirement already satisfied: importlib-metadata in c:\users\aksha\anaconda3\lib\site-packages (from dash) (6.0.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\aksha\anaconda3\lib\site-packages (from dash) (4.7.1)
# Requirement already satisfied: setuptools in c:\users\aksha\anaconda3\lib\site-packages (from dash) (68.0.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\aksha\anaconda3\lib\site-packages (from plotly) (8.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\aksha\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\aksha\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\aksha\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\aksha\anaconda3\lib\site-packages (from pandas) (1.24.3)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\aksha\anaconda3\lib\site-packages (from flask->jupyter-dash) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\aksha\anaconda3\lib\site-packages (from flask->jupyter-dash) (2.0.1)
# Requirement already satisfied: click>=8.0 in c:\users\aksha\anaconda3\lib\site-packages (from flask->jupyter-dash) (8.0.4)
# Requirement already satisfied: six>=1.5 in c:\users\aksha\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\aksha\anaconda3\lib\site-packages (from Werkzeug<3.1->dash) (2.1.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\aksha\anaconda3\lib\site-packages (from importlib-metadata->dash) (3.11.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\aksha\anaconda3\lib\site-packages (from ipykernel->jupyter-dash) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\aksha\anaconda3\lib\site-packages (from ipykernel->jupyter-dash) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\aksha\anaconda3\lib\site-packages (from ipykernel->jupyter-dash) (7.4.9)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\aksha\anaconda3\lib\site-packages (from ipykernel->jupyter-dash) (5.3.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\aksha\anaconda3\lib\site-packages (from ipykernel->jupyter-dash) (0.1.6)
# Requirement already satisfied: packaging in c:\users\aksha\anaconda3\lib\site-packages (from ipykernel->jupyter-dash) (23.1)
# Requirement already satisfied: psutil in c:\users\aksha\anaconda3\lib\site-packages (from ipykernel->jupyter-dash) (5.9.0)
# Requirement already satisfied: pyzmq>=20 in c:\users\aksha\anaconda3\lib\site-packages (from ipykernel->jupyter-dash) (23.2.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\aksha\anaconda3\lib\site-packages (from ipykernel->jupyter-dash) (6.3.2)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\aksha\anaconda3\lib\site-packages (from ipykernel->jupyter-dash) (5.7.1)
# Requirement already satisfied: backcall in c:\users\aksha\anaconda3\lib\site-packages (from ipython->jupyter-dash) (0.2.0)
# Requirement already satisfied: decorator in c:\users\aksha\anaconda3\lib\site-packages (from ipython->jupyter-dash) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\aksha\anaconda3\lib\site-packages (from ipython->jupyter-dash) (0.18.1)
# Requirement already satisfied: pickleshare in c:\users\aksha\anaconda3\lib\site-packages (from ipython->jupyter-dash) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\aksha\anaconda3\lib\site-packages (from ipython->jupyter-dash) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\aksha\anaconda3\lib\site-packages (from ipython->jupyter-dash) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\aksha\anaconda3\lib\site-packages (from ipython->jupyter-dash) (0.2.0)
# Requirement already satisfied: colorama in c:\users\aksha\anaconda3\lib\site-packages (from ipython->jupyter-dash) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\aksha\anaconda3\lib\site-packages (from requests->jupyter-dash) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aksha\anaconda3\lib\site-packages (from requests->jupyter-dash) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\aksha\anaconda3\lib\site-packages (from requests->jupyter-dash) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aksha\anaconda3\lib\site-packages (from requests->jupyter-dash) (2024.8.30)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\aksha\anaconda3\lib\site-packages (from jedi>=0.16->ipython->jupyter-dash) (0.8.3)
# Requirement already satisfied: entrypoints in c:\users\aksha\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter-dash) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\aksha\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter-dash) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\aksha\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter-dash) (305.1)
# Requirement already satisfied: wcwidth in c:\users\aksha\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython->jupyter-dash) (0.2.5)
# Requirement already satisfied: executing in c:\users\aksha\anaconda3\lib\site-packages (from stack-data->ipython->jupyter-dash) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\aksha\anaconda3\lib\site-packages (from stack-data->ipython->jupyter-dash) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\aksha\anaconda3\lib\site-packages (from stack-data->ipython->jupyter-dash) (0.2.2)
# Downloading jupyter_dash-0.4.2-py3-none-any.whl (23 kB)
# Downloading ansi2html-1.9.2-py3-none-any.whl (17 kB)
# Installing collected packages: ansi2html, jupyter-dash
# Successfully installed ansi2html-1.9.2 jupyter-dash-0.4.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import required libraries
import pandas as pd
import dash
from jupyter_dash import JupyterDash  # Import JupyterDash
import dash_html_components as html
import dash_core_components as dcc
from dash.dependencies import Input, Output
import plotly.express as px

# Read the dataset
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_dash.csv"
spacex_df = pd.read_csv(url)

max_payload = spacex_df['Payload Mass (kg)'].max()
min_payload = spacex_df['Payload Mass (kg)'].min()

# Create a JupyterDash app
app = JupyterDash(__name__)

# App layout
app.layout = html.Div(children=[
    html.H1('SpaceX Launch Records Dashboard',
            style={'textAlign': 'center', 'color': '#503D36', 'font-size': 40}),
    
    dcc.Dropdown(id='site-dropdown',
                 options=[
                     {'label': 'All Sites', 'value': 'All Sites'},
                     {'label': 'CCAFS LC-40', 'value': 'CCAFS LC-40'},
                     {'label': 'VAFB SLC-4E', 'value': 'VAFB SLC-4E'},
                     {'label': 'KSC LC-39A', 'value': 'KSC LC-39A'},
                     {'label': 'CCAFS SLC-40', 'value': 'CCAFS SLC-40'}
                 ],
                 placeholder='Select a Launch Site Here',
                 value='All Sites',
                 searchable=True
                 ),
    html.Br(),

    html.Div(dcc.Graph(id='success-pie-chart')),
    html.Br(),

    html.P("Payload range (Kg):"),
    dcc.RangeSlider(id='payload-slider',
                    min=0, max=10000, step=1000,
                    marks={i: '{}'.format(i) for i in range(0, 10001, 1000)},
                    value=[min_payload, max_payload]),

    html.Div(dcc.Graph(id='success-payload-scatter-chart')),
])

# Callback for pie chart
@app.callback(Output('success-pie-chart', 'figure'),
              Input('site-dropdown', 'value'))
def get_pie_chart(launch_site):
    if launch_site == 'All Sites':
        fig = px.pie(values=spacex_df.groupby('Launch Site')['class'].mean(), 
                     names=spacex_df.groupby('Launch Site')['Launch Site'].first(),
                     title='Total Success Launches by Site')
    else:
        fig = px.pie(values=spacex_df[spacex_df['Launch Site'] == launch_site]['class'].value_counts(normalize=True),
                     names=spacex_df['class'].unique(),
                     title=f'Total Success Launches for Site {launch_site}')
    return fig

# Callback for scatter plot
@app.callback(Output('success-payload-scatter-chart', 'figure'),
              [Input('site-dropdown', 'value'),
               Input('payload-slider', 'value')])
def get_payload_chart(launch_site, payload_mass):
    filtered_df = spacex_df[spacex_df['Payload Mass (kg)'].between(payload_mass[0], payload_mass[1])]
    if launch_site == 'All Sites':
        fig = px.scatter(filtered_df, x="Payload Mass (kg)", y="class",
                         color="Booster Version Category",
                         hover_data=['Launch Site'],
                         title='Correlation Between Payload and Success for All Sites')
    else:
        df = filtered_df[filtered_df['Launch Site'] == launch_site]
        fig = px.scatter(df, x="Payload Mass (kg)", y="class",
                         color="Booster Version Category",
                         hover_data=['Launch Site'],
                         title=f'Correlation Between Payload and Success for Site {launch_site}')
    return fig

# Run the Dash app inside Jupyter Notebook
app.run_server(mode='inline')
# Out:
# C:\Users\aksha\anaconda3\Lib\site-packages\dash\dash.py:579: UserWarning:
#
# JupyterDash is deprecated, use Dash instead.
# See https://dash.plotly.com/dash-in-jupyter for more details.
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\plotly\express\_chart_types.py:66, in scatter(
#     data_frame=    Unnamed: 0  Flight Number   Launch Site  cla...4
# 55  F9 B4  B1040.2                       B4  ,
#     x='Payload Mass (kg)',
#     y='class',
#     color='Booster Version Category',
#     symbol=None,
#     size=None,
#     hover_name=None,
#     hover_data=['Launch Site'],
#     custom_data=None,
#     text=None,
#     facet_row=None,
#     facet_col=None,
#     facet_col_wrap=0,
#     facet_row_spacing=None,
#     facet_col_spacing=None,
#     error_x=None,
#     error_x_minus=None,
#     error_y=None,
#     error_y_minus=None,
#     animation_frame=None,
#     animation_group=None,
#     category_orders=None,
#     labels=None,
#     orientation=None,
#     color_discrete_sequence=None,
#     color_discrete_map=None,
#     color_continuous_scale=None,
#     range_color=None,
#     color_continuous_midpoint=None,
#     symbol_sequence=None,
#     symbol_map=None,
#     opacity=None,
#     size_max=None,
#     marginal_x=None,
#     marginal_y=None,
#     trendline=None,
#     trendline_options=None,
#     trendline_color_override=None,
#     trendline_scope='trace',
#     log_x=False,
#     log_y=False,
#     range_x=None,
#     range_y=None,
#     render_mode='auto',
#     title='Correlation Between Payload and Success for All Sites',
#     template=None,
#     width=None,
#     height=None
# )
#      12 def scatter(
#      13     data_frame=None,
#      14     x=None,
#    (...)
#      60     height=None,
#      61 ) -> go.Figure:
#      62     """
#      63     In a scatter plot, each row of `data_frame` is represented by a symbol
#      64     mark in 2D space.
#      65     """
# ---> 66     return make_figure(args=locals(), constructor=go.Scatter)
#         go = <module 'plotly.graph_objs' from 'C:\\Users\\aksha\\anaconda3\\Lib\\site-packages\\plotly\\graph_objs\\__init__.py'>
#
# File ~\anaconda3\Lib\site-packages\plotly\express\_core.py:1988, in make_figure(
#     args={'animation_frame': None, 'animation_group': None, 'category_orders': None, 'color': 'Booster Version Category', 'color_continuous_midpoint': None, 'color_continuous_scale': None, 'color_discrete_map': None, 'color_discrete_sequence': None, 'custom_data': None, 'data_frame':     Unnamed: 0  Flight Number   Launch Site  cla...4
# 55  F9 B4  B1040.2                       B4  , ...},
#     constructor=<class 'plotly.graph_objs._scatter.Scatter'>,
#     trace_patch={},
#     layout_patch={}
# )
#    1986 trace_patch = trace_patch or {}
#    1987 layout_patch = layout_patch or {}
# -> 1988 apply_default_cascade(args)
#         args = {'data_frame':     Unnamed: 0  Flight Number   Launch Site  class  Payload Mass (kg)  \
# 0            0              1   CCAFS LC-40      0               0.00
# 1            1              2   CCAFS LC-40      0               0.00
# 2            2              3   CCAFS LC-40      0             525.00
# 3            3              4   CCAFS LC-40      0             500.00
# 4            4              5   CCAFS LC-40      0             677.00
# 5            5              7   CCAFS LC-40      0            3170.00
# 6            6              8   CCAFS LC-40      0            3325.00
# 7            7              9   CCAFS LC-40      0            2296.00
# 8            8             10   CCAFS LC-40      0            1316.00
# 9            9             11   CCAFS LC-40      0            4535.00
# 10          10             12   CCAFS LC-40      0            4428.00
# 11          11             13   CCAFS LC-40      0            2216.00
# 12          12             14   CCAFS LC-40      0            2395.00
# 13          13             15   CCAFS LC-40      0             570.00
# 14          14             16   CCAFS LC-40      0            4159.00
# 15          15             17   CCAFS LC-40      0            1898.00
# 16          16             18   CCAFS LC-40      0            4707.00
# 17          17             19   CCAFS LC-40      1            1952.00
# 18          18             20   CCAFS LC-40      1            2034.00
# 19          19             22   CCAFS LC-40      0            5271.00
# 20          20             23   CCAFS LC-40      1            3136.00
# 21          21             24   CCAFS LC-40      1            4696.00
# 22          22             25   CCAFS LC-40      1            3100.00
# 23          23             26   CCAFS LC-40      0            3600.00
# 24          24             27   CCAFS LC-40      1            2257.00
# 25          25             28   CCAFS LC-40      1            4600.00
# 26          26              6   VAFB SLC-4E      0             500.00
# 27          27             21   VAFB SLC-4E      0             553.00
# 28          28             29   VAFB SLC-4E      1            9600.00
# 29          29             37   VAFB SLC-4E      1            9600.00
# 30          30             40   VAFB SLC-4E      1             475.00
# 31          31             42   VAFB SLC-4E      1            9600.00
# 32          32             46   VAFB SLC-4E      0            9600.00
# 33          33             49   VAFB SLC-4E      0            2150.00
# 34          34             51   VAFB SLC-4E      0            9600.00
# 35          35             55   VAFB SLC-4E      0            6460.00
# 36          36             30    KSC LC-39A      1            2490.00
# 37          37             31    KSC LC-39A      0            5600.00
# 38          38             32    KSC LC-39A      1            5300.00
# 39          39             33    KSC LC-39A      1            3696.65
# 40          40             34    KSC LC-39A      0            6070.00
# 41          41             35    KSC LC-39A      1            2708.00
# 42          42             36    KSC LC-39A      1            3669.00
# 43          43             38    KSC LC-39A      0            6761.00
# 44          44             39    KSC LC-39A      1            3310.00
# 45          45             41    KSC LC-39A      1            4990.00
# 46          46             43    KSC LC-39A      1            5200.00
# 47          47             44    KSC LC-39A      1            3500.00
# 48          48             54    KSC LC-39A      1            3600.00
# 49          49             45  CCAFS SLC-40      1            2205.00
# 50          50             47  CCAFS SLC-40      1            3696.65
# 51          51             48  CCAFS SLC-40      0            4230.00
# 52          52             50  CCAFS SLC-40      0            6092.00
# 53          53             52  CCAFS SLC-40      0            2647.00
# 54          54             53  CCAFS SLC-40      1             362.00
# 55          55             56  CCAFS SLC-40      0            5384.00
#
#    Booster Version Booster Version Category
# 0   F9 v1.0  B0003                     v1.0
# 1   F9 v1.0  B0004                     v1.0
# 2   F9 v1.0  B0005                     v1.0
# 3   F9 v1.0  B0006                     v1.0
# 4   F9 v1.0  B0007                     v1.0
# 5          F9 v1.1                     v1.1
# 6          F9 v1.1                     v1.1
# 7          F9 v1.1                     v1.1
# 8          F9 v1.1                     v1.1
# 9          F9 v1.1                     v1.1
# 10   F9 v1.1 B1011                     v1.1
# 11   F9 v1.1 B1010                     v1.1
# 12   F9 v1.1 B1012                     v1.1
# 13   F9 v1.1 B1013                     v1.1
# 14   F9 v1.1 B1014                     v1.1
# 15   F9 v1.1 B1015                     v1.1
# 16   F9 v1.1 B1016                     v1.1
# 17   F9 v1.1 B1018                     v1.1
# 18     F9 FT B1019                       FT
# 19     F9 FT B1020                       FT
# 20   F9 FT B1021.1                       FT
# 21     F9 FT B1022                       FT
# 22   F9 FT B1023.1                       FT
# 23     F9 FT B1024                       FT
# 24   F9 FT B1025.1                       FT
# 25     F9 FT B1026                       FT
# 26  F9 v1.1  B1003                     v1.1
# 27   F9 v1.1 B1017                     v1.1
# 28   F9 FT B1029.1                       FT
# 29   F9 FT B1036.1                       FT
# 30   F9 FT B1038.1                       FT
# 31   F9 B4 B1041.1                       B4
# 32  F9 FT  B1036.2                       FT
# 33  F9 FT  B1038.2                       FT
# 34  F9 B4  B1041.2                       B4
# 35  F9 B4  B1043.2                       B4
# 36   F9 FT B1031.1                       FT
# 37     F9 FT B1030                       FT
# 38  F9 FT  B1021.2                       FT
# 39   F9 FT B1032.1                       FT
# 40     F9 FT B1034                       FT
# 41   F9 FT B1035.1                       FT
# 42  F9 FT  B1029.2                       FT
# 43     F9 FT B1037                       FT
# 44   F9 B4 B1039.1                       B4
# 45   F9 B4 B1040.1                       B4
# 46  F9 FT  B1031.2                       FT
# 47   F9 B4 B1042.1                       B4
# 48  F9 B5  B1046.1                       B5
# 49  F9 FT  B1035.2                       FT
# 50   F9 B4 B1043.1                       B4
# 51  F9 FT  B1032.2                       FT
# 52     F9 B4 B1044                       B4
# 53  F9 B4  B1039.2                       B4
# 54   F9 B4 B1045.1                       B4
# 55  F9 B4  B1040.2                       B4  , 'x': 'Payload Mass (kg)', 'y': 'class', 'color': 'Booster Version Category', 'symbol': None, 'size': None, 'hover_name': None, 'hover_data': ['Launch Site'], 'custom_data': None, 'text': None, 'facet_row': None, 'facet_col': None, 'facet_col_wrap': 0, 'facet_row_spacing': None, 'facet_col_spacing': None, 'error_x': None, 'error_x_minus': None, 'error_y': None, 'error_y_minus': None, 'animation_frame': None, 'animation_group': None, 'category_orders': None, 'labels': None, 'orientation': None, 'color_discrete_sequence': None, 'color_discrete_map': None, 'color_continuous_scale': None, 'range_color': None, 'color_continuous_midpoint': None, 'symbol_sequence': None, 'symbol_map': None, 'opacity': None, 'size_max': None, 'marginal_x': None, 'marginal_y': None, 'trendline': None, 'trendline_options': None, 'trendline_color_override': None, 'trendline_scope': 'trace', 'log_x': False, 'log_y': False, 'range_x': None, 'range_y': None, 'render_mode': 'auto', 'title': 'Correlation Between Payload and Success for All Sites', 'template': None, 'width': None, 'height': None}
#    1990 args = build_dataframe(args, constructor)
#    1991 if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
#
# File ~\anaconda3\Lib\site-packages\plotly\express\_core.py:946, in apply_default_cascade(
#     args={'animation_frame': None, 'animation_group': None, 'category_orders': None, 'color': 'Booster Version Category', 'color_continuous_midpoint': None, 'color_continuous_scale': None, 'color_discrete_map': None, 'color_discrete_sequence': None, 'custom_data': None, 'data_frame':     Unnamed: 0  Flight Number   Launch Site  cla...4
# 55  F9 B4  B1040.2                       B4  , ...}
# )
#     944 if "symbol_sequence" in args:
#     945     if args["symbol_sequence"] is None and args["template"].data.scatter:
# --> 946         args["symbol_sequence"] = [
#         args = {'data_frame':     Unnamed: 0  Flight Number   Launch Site  class  Payload Mass (kg)  \
# 0            0              1   CCAFS LC-40      0               0.00
# 1            1              2   CCAFS LC-40      0               0.00
# 2            2              3   CCAFS LC-40      0             525.00
# 3            3              4   CCAFS LC-40      0             500.00
# 4            4              5   CCAFS LC-40      0             677.00
# 5            5              7   CCAFS LC-40      0            3170.00
# 6            6              8   CCAFS LC-40      0            3325.00
# 7            7              9   CCAFS LC-40      0            2296.00
# 8            8             10   CCAFS LC-40      0            1316.00
# 9            9             11   CCAFS LC-40      0            4535.00
# 10          10             12   CCAFS LC-40      0            4428.00
# 11          11             13   CCAFS LC-40      0            2216.00
# 12          12             14   CCAFS LC-40      0            2395.00
# 13          13             15   CCAFS LC-40      0             570.00
# 14          14             16   CCAFS LC-40      0            4159.00
# 15          15             17   CCAFS LC-40      0            1898.00
# 16          16             18   CCAFS LC-40      0            4707.00
# 17          17             19   CCAFS LC-40      1            1952.00
# 18          18             20   CCAFS LC-40      1            2034.00
# 19          19             22   CCAFS LC-40      0            5271.00
# 20          20             23   CCAFS LC-40      1            3136.00
# 21          21             24   CCAFS LC-40      1            4696.00
# 22          22             25   CCAFS LC-40      1            3100.00
# 23          23             26   CCAFS LC-40      0            3600.00
# 24          24             27   CCAFS LC-40      1            2257.00
# 25          25             28   CCAFS LC-40      1            4600.00
# 26          26              6   VAFB SLC-4E      0             500.00
# 27          27             21   VAFB SLC-4E      0             553.00
# 28          28             29   VAFB SLC-4E      1            9600.00
# 29          29             37   VAFB SLC-4E      1            9600.00
# 30          30             40   VAFB SLC-4E      1             475.00
# 31          31             42   VAFB SLC-4E      1            9600.00
# 32          32             46   VAFB SLC-4E      0            9600.00
# 33          33             49   VAFB SLC-4E      0            2150.00
# 34          34             51   VAFB SLC-4E      0            9600.00
# 35          35             55   VAFB SLC-4E      0            6460.00
# 36          36             30    KSC LC-39A      1            2490.00
# 37          37             31    KSC LC-39A      0            5600.00
# 38          38             32    KSC LC-39A      1            5300.00
# 39          39             33    KSC LC-39A      1            3696.65
# 40          40             34    KSC LC-39A      0            6070.00
# 41          41             35    KSC LC-39A      1            2708.00
# 42          42             36    KSC LC-39A      1            3669.00
# 43          43             38    KSC LC-39A      0            6761.00
# 44          44             39    KSC LC-39A      1            3310.00
# 45          45             41    KSC LC-39A      1            4990.00
# 46          46             43    KSC LC-39A      1            5200.00
# 47          47             44    KSC LC-39A      1            3500.00
# 48          48             54    KSC LC-39A      1            3600.00
# 49          49             45  CCAFS SLC-40      1            2205.00
# 50          50             47  CCAFS SLC-40      1            3696.65
# 51          51             48  CCAFS SLC-40      0            4230.00
# 52          52             50  CCAFS SLC-40      0            6092.00
# 53          53             52  CCAFS SLC-40      0            2647.00
# 54          54             53  CCAFS SLC-40      1             362.00
# 55          55             56  CCAFS SLC-40      0            5384.00
#
#    Booster Version Booster Version Category
# 0   F9 v1.0  B0003                     v1.0
# 1   F9 v1.0  B0004                     v1.0
# 2   F9 v1.0  B0005                     v1.0
# 3   F9 v1.0  B0006                     v1.0
# 4   F9 v1.0  B0007                     v1.0
# 5          F9 v1.1                     v1.1
# 6          F9 v1.1                     v1.1
# 7          F9 v1.1                     v1.1
# 8          F9 v1.1                     v1.1
# 9          F9 v1.1                     v1.1
# 10   F9 v1.1 B1011                     v1.1
# 11   F9 v1.1 B1010                     v1.1
# 12   F9 v1.1 B1012                     v1.1
# 13   F9 v1.1 B1013                     v1.1
# 14   F9 v1.1 B1014                     v1.1
# 15   F9 v1.1 B1015                     v1.1
# 16   F9 v1.1 B1016                     v1.1
# 17   F9 v1.1 B1018                     v1.1
# 18     F9 FT B1019                       FT
# 19     F9 FT B1020                       FT
# 20   F9 FT B1021.1                       FT
# 21     F9 FT B1022                       FT
# 22   F9 FT B1023.1                       FT
# 23     F9 FT B1024                       FT
# 24   F9 FT B1025.1                       FT
# 25     F9 FT B1026                       FT
# 26  F9 v1.1  B1003                     v1.1
# 27   F9 v1.1 B1017                     v1.1
# 28   F9 FT B1029.1                       FT
# 29   F9 FT B1036.1                       FT
# 30   F9 FT B1038.1                       FT
# 31   F9 B4 B1041.1                       B4
# 32  F9 FT  B1036.2                       FT
# 33  F9 FT  B1038.2                       FT
# 34  F9 B4  B1041.2                       B4
# 35  F9 B4  B1043.2                       B4
# 36   F9 FT B1031.1                       FT
# 37     F9 FT B1030                       FT
# 38  F9 FT  B1021.2                       FT
# 39   F9 FT B1032.1                       FT
# 40     F9 FT B1034                       FT
# 41   F9 FT B1035.1                       FT
# 42  F9 FT  B1029.2                       FT
# 43     F9 FT B1037                       FT
# 44   F9 B4 B1039.1                       B4
# 45   F9 B4 B1040.1                       B4
# 46  F9 FT  B1031.2                       FT
# 47   F9 B4 B1042.1                       B4
# 48  F9 B5  B1046.1                       B5
# 49  F9 FT  B1035.2                       FT
# 50   F9 B4 B1043.1                       B4
# 51  F9 FT  B1032.2                       FT
# 52     F9 B4 B1044                       B4
# 53  F9 B4  B1039.2                       B4
# 54   F9 B4 B1045.1                       B4
# 55  F9 B4  B1040.2                       B4  , 'x': 'Payload Mass (kg)', 'y': 'class', 'color': 'Booster Version Category', 'symbol': None, 'size': None, 'hover_name': None, 'hover_data': ['Launch Site'], 'custom_data': None, 'text': None, 'facet_row': None, 'facet_col': None, 'facet_col_wrap': 0, 'facet_row_spacing': None, 'facet_col_spacing': None, 'error_x': None, 'error_x_minus': None, 'error_y': None, 'error_y_minus': None, 'animation_frame': None, 'animation_group': None, 'category_orders': None, 'labels': None, 'orientation': None, 'color_discrete_sequence': None, 'color_discrete_map': None, 'color_continuous_scale': None, 'range_color': None, 'color_continuous_midpoint': None, 'symbol_sequence': None, 'symbol_map': None, 'opacity': None, 'size_max': None, 'marginal_x': None, 'marginal_y': None, 'trendline': None, 'trendline_options': None, 'trendline_color_override': None, 'trendline_scope': 'trace', 'log_x': False, 'log_y': False, 'range_x': None, 'range_y': None, 'render_mode': 'auto', 'title': 'Correlation Between Payload and Success for All Sites', 'template': None, 'width': None, 'height': None}
#         args["symbol_sequence"] = None
#         args["template"] = None
#     947             scatter.marker.symbol for scatter in args["template"].data.scatter
#     948         ]
#     949     if not args["symbol_sequence"] or not any(args["symbol_sequence"]):
#     950         args["symbol_sequence"] = ["circle", "diamond", "square", "x", "cross"]
#
# File ~\anaconda3\Lib\site-packages\plotly\express\_core.py:947, in <listcomp>(.0=<tuple_iterator object>)
#     944 if "symbol_sequence" in args:
#     945     if args["symbol_sequence"] is None and args["template"].data.scatter:
#     946         args["symbol_sequence"] = [
# --> 947             scatter.marker.symbol for scatter in args["template"].data.scatter
#         Exception trying to inspect frame. No more locals available.
#     948         ]
#     949     if not args["symbol_sequence"] or not any(args["symbol_sequence"]):
#     950         args["symbol_sequence"] = ["circle", "diamond", "square", "x", "cross"]
#
# File ~\anaconda3\Lib\site-packages\plotly\graph_objs\scatter\_marker.py:1065, in Marker.symbol(
#     self=<class 'plotly.graph_objs.scatter._marker.Marker'> instance
# )
#     962 @property
#     963 def symbol(self):
#     964     """
#     965     Sets the marker symbol type. Adding 100 is equivalent to
#     966     appending "-open" to a symbol name. Adding 200 is equivalent to
#    (...)
#    1063     Any|numpy.ndarray
#    1064     """
# -> 1065     return self["symbol"]
#         Exception trying to inspect frame. No more locals available.
#
# File ~\anaconda3\Lib\site-packages\plotly\basedatatypes.py:4733, in BasePlotlyType.__getitem__(
#     self=<class 'plotly.graph_objs.scatter._marker.Marker'> instance,
#     prop='symbol'
# )
#    4730             self._compound_array_props[prop] = []
#    4732     return validator.present(self._compound_array_props[prop])
# -> 4733 elif self._props is not None and prop in self._props:
#         prop = 'symbol'
#         Exception trying to inspect frame. No more locals available.
#    4734     return validator.present(self._props[prop])
#    4735 elif self._prop_defaults is not None:
#
# File ~\anaconda3\Lib\site-packages\plotly\basedatatypes.py:4428, in BasePlotlyType._props(
#     self=<class 'plotly.graph_objs.scatter._marker.Marker'> instance
# )
#    4425     return self._orphan_props
#    4426 else:
#    4427     # Get data from parent's dict
# -> 4428     return self.parent._get_child_props(self)
#         Exception trying to inspect frame. No more locals available.
#
# File ~\anaconda3\Lib\site-packages\plotly\basedatatypes.py:4442, in BasePlotlyType._get_child_props(
#     self=<class 'plotly.graph_objs._scatter.Scatter'> instance,
#     child=<class 'plotly.graph_objs.scatter._marker.Marker'> instance
# )
#    4430 def _get_child_props(self, child):
#    4431     """
#    4432     Return properties dict for child
#    4433
#    (...)
#    4440     dict
#    4441     """
# -> 4442     if self._props is None:
#         Exception trying to inspect frame. No more locals available.
#    4443         # If this node's properties are uninitialized then so are its
#    4444         # child's
#    4445         return None
#    4446     else:
#    4447         # ### Child a compound property ###
#
# File ~\anaconda3\Lib\site-packages\plotly\basedatatypes.py:4428, in BasePlotlyType._props(
#     self=<class 'plotly.graph_objs._scatter.Scatter'> instance
# )
#    4425     return self._orphan_props
#    4426 else:
#    4427     # Get data from parent's dict
# -> 4428     return self.parent._get_child_props(self)
#         Exception trying to inspect frame. No more locals available.
#
# File ~\anaconda3\Lib\site-packages\plotly\basedatatypes.py:4462, in BasePlotlyType._get_child_props(
#     self=layout.template.Data({
#     'bar': [{'error_x': {...': 'white'}},
#                'type': 'table'}]
# }),
#     child=<class 'plotly.graph_objs._scatter.Scatter'> instance
# )
#    4460 elif isinstance(validator, CompoundArrayValidator):
#    4461     children = self[child.plotly_name]
# -> 4462     child_ind = BaseFigure._index_is(children, child)
#         Exception trying to inspect frame. No more locals available.
#    4463     assert child_ind is not None
#    4465     children_props = self._props.get(child.plotly_name, None)
#
# File ~\anaconda3\Lib\site-packages\plotly\basedatatypes.py:3960, in BaseFigure._index_is(
#     iterable=(Scatter({
#     'fillpattern': {'fillmode': 'overlay', 'size': 10, 'solidity': 0.2}
# }),),
#     val=<class 'plotly.graph_objs._scatter.Scatter'> instance
# )
#    3958 index_list = [i for i, curr_val in enumerate(iterable) if curr_val is val]
#    3959 if not index_list:
# -> 3960     raise ValueError("Invalid value")
#    3962 return index_list[0]
#
# ValueError: Invalid value
